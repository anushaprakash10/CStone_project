# %% [markdown]
# Data Dictionary:
#
# 1. ID: Unique id of the patient
#
# 2. Age : Age of the patient
#
# 3. Gender : Gender of the patient
#
# 4. TB : Total Bilirubin5.DB : Direct Bilirubin
#
# 6. Alkphos: Alkaline Phosphotase
#
# 7. Sgpt:  Alamine Aminotransferase
#
# 8. Sgot:  Aspartate Aminotransferase
#
# 9. TP:  Total Protiens
#
# 10. ALB:  Albumin
#
# 11. A/G Ratio : Albumin and Globulin Ratio
#
# 12. State_Code: Patient state
#
# 13. City_Code: Patient city

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/MSII/Desktop/Capstone3_Healthcare/Liver Patient Dataset.csv",encoding="ISO-8859-1")

# %%
df
# Out:
#              ID  Age of the patient Gender of the patient  Total Bilirubin  \
# 0        ID_001                65.0                Female              0.7
# 1        ID_002                62.0                  Male             10.9
# 2        ID_003                62.0                  Male              7.3
# 3        ID_004                58.0                  Male              1.0
# 4        ID_005                72.0                  Male              3.9
# ...         ...                 ...                   ...              ...
# 30672  ID_30673                57.0                Female              2.6
# 30673  ID_30674                45.0                  Male              1.3
# 30674  ID_30675                60.0                Female              0.7
# 30675  ID_30676                45.0                  Male             14.2
# 30676  ID_30677                23.0                  Male              1.4
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# ...

# %%
df.describe()
# Out:
#        Age of the patient  Total Bilirubin  Direct Bilirubin  \
# count        30675.000000     30033.000000      30119.000000
# mean            44.107971         3.370629          1.528225
# std             15.981066         6.256466          2.870060
# min              4.000000         0.400000          0.100000
# 25%             32.000000         0.800000          0.200000
# 50%             45.000000         1.000000          0.300000
# 75%             55.000000         2.700000          1.300000
# max             90.000000        75.000000         19.700000
#
#         Alkphos Alkaline Phosphotase   Sgpt Alamine Aminotransferase  \
# count                   29880.000000                    30139.000000
# mean                      289.048293                       81.479711
# std                       238.570823                      182.184895
# min                        63.000000                       10.000000
# ...

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
df2 = pd.read_excel("C:/Users/MSII/Desktop/Capstone3_Healthcare/Status.xlsx")

# %%
df2
# Out:
#              ID  Status
# 0        ID_001       1
# 1        ID_002       1
# 2        ID_003       1
# 3        ID_004       1
# 4        ID_005       1
# ...         ...     ...
# 30672  ID_30673       2
# 30673  ID_30674       1
# 30674  ID_30675       2
# 30675  ID_30676       1
# 30676  ID_30677       1
#
# [30677 rows x 2 columns]

# %%
df_final =pd.merge(df,df2,on="ID")

# %%
df_final
# Out:
#              ID  Age of the patient Gender of the patient  Total Bilirubin  \
# 0        ID_001                65.0                Female              0.7
# 1        ID_002                62.0                  Male             10.9
# 2        ID_003                62.0                  Male              7.3
# 3        ID_004                58.0                  Male              1.0
# 4        ID_005                72.0                  Male              3.9
# ...         ...                 ...                   ...              ...
# 30672  ID_30673                57.0                Female              2.6
# 30673  ID_30674                45.0                  Male              1.3
# 30674  ID_30675                60.0                Female              0.7
# 30675  ID_30676                45.0                  Male             14.2
# 30676  ID_30677                23.0                  Male              1.4
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# ...

# %% [markdown]
# # from here

# %%
# Plotting the Number of patients with liver disease vs Number of patients with no liver disease
sns.countplot(data=df_final, x = 'Status', label='Count')

LD, NLD = df_final['Status'].value_counts()
print('Number of patients diagnosed with liver disease: ',LD)
print('Number of patients not diagnosed with liver disease: ',NLD)
# Out:
# Number of patients diagnosed with liver disease:  21907
# Number of patients not diagnosed with liver disease:  8770

# %%
# Plotting patient Age vs Gender
#sns.catplot(x="Age of the patient", y="Gender of the patient", hue="Status", data=df_final)

# %%
df_final[['Gender of the patient', 'Status','Age of the patient']].groupby(['Status','Gender of the patient'], as_index=False).mean().sort_values(by='Status', ascending=False)
# Out:
#    Status Gender of the patient  Age of the patient
# 2       2                Female           43.068889
# 3       2                  Male           44.304982
# 0       1                Female           43.290166
# 1       1                  Male           44.503496

# %%
# Plotting Age vs Gender
g = sns.FacetGrid(df_final, col="Status", row="Gender of the patient", margin_titles=True)
g.map(plt.hist, "Age of the patient", color="red")
plt.subplots_adjust(top=0.9)
g.fig.suptitle(' Liver Disease by Gender and Age')
# Out:
# Text(0.5, 0.98, ' Liver Disease by Gender and Age')

# %%
# Plotting Gender(Male/Female) along with Total_Bilirubin and Direct_Bilirubin

g = sns.FacetGrid(df_final, col="Gender of the patient", row="Status", margin_titles=True)
g.map(plt.scatter,"Direct Bilirubin", "Total Bilirubin", edgecolor="w")
plt.subplots_adjust(top=0.9)

# %%
# Plotting Total_Bilirubin vs Direct_Bilirubin
#sns.jointplot("Total_Bilirubin", "Direct_Bilirubin", data=df_final, kind="reg")
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30677 entries, 0 to 30676
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    30677 non-null  object
#  1   Age of the patient                    30675 non-null  float64
#  2   Gender of the patient                 29779 non-null  object
#  3   Total Bilirubin                       30033 non-null  float64
#  4   Direct Bilirubin                      30119 non-null  float64
#  5    Alkphos Alkaline Phosphotase         29880 non-null  float64
#  6    Sgpt Alamine Aminotransferase        30139 non-null  float64
#  7   Sgot Aspartate Aminotransferase       30214 non-null  float64
#  8   Total Protiens                        30213 non-null  float64
#  9    ALB Albumin                          30183 non-null  float64
# ...

# %%
# Plotting Gender(Male/Female) along with Aspartate Aminotransferase, Alamine Aminotransferase
g = sns.FacetGrid(df_final, col="Gender of the patient", row="Status", margin_titles=True)
g.map(plt.scatter,"Sgpt Alamine Aminotransferase", "Sgot Aspartate Aminotransferase",  edgecolor="w")
plt.subplots_adjust(top=0.9)

# %%
# Plotting Aspartate_Aminotransferase vs Alamine_Aminotransferase
#sns.jointplot("Sgot Aspartate Aminotransferase", "Sgpt Alamine Aminotransferase", data=df_final, kind="reg")

sns.jointplot(data=df_final, x="Sgot Aspartate Aminotransferase", y=" Sgpt Alamine Aminotransferase")

# %%
# Plotting Gender(Male/Female) along with Alkaline_Phosphotase and Alamine_Aminotransferase

g = sns.FacetGrid(df_final, col="Gender of the patient", row="Status", margin_titles=True)
g.map(plt.scatter," Alkphos Alkaline Phosphotase", " Sgpt Alamine Aminotransferase",  edgecolor="w")
plt.subplots_adjust(top=0.9)

# %%
df_final.columns
# Out:
# Index(['ID', 'Age of the patient', 'Gender of the patient', 'Total Bilirubin',
#        'Direct Bilirubin', ' Alkphos Alkaline Phosphotase',
#        ' Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase',
#        'Total Protiens', ' ALB Albumin',
#        'A/G Ratio Albumin and Globulin Ratio', 'City_Code', 'State_Code',
#        'Status'],
#       dtype='object')

# %%
# Plotting Alkaline_Phosphotase vs Alamine_Aminotransferase
#sns.jointplot(" Alkphos Alkaline Phosphotase", " Sgpt Alamine Aminotransferase", data=df_final)
sns.jointplot(x = " Alkphos Alkaline Phosphotase", y = " Sgpt Alamine Aminotransferase", 
              kind = "reg", data = df_final, dropna = True)

# %%
# Plotting Gender(Male/Female) along with Total_Protiens and Albumin
g = sns.FacetGrid( df_final, col="Gender of the patient", row="Status", margin_titles=True)
g.map(plt.scatter,"Total Protiens", "ALB_Albumin",  edgecolor="w")
plt.subplots_adjust(top=0.9)

# %%
df_final.rename(columns={' ALB Albumin': 'ALB_Albumin'}, inplace=True)

# %%
# Plotting Gender(Male/Female) along with Albumin and Albumin_and_Globulin_Ratio
g = sns.FacetGrid(df_final, col="Gender of the patient", row="Status", margin_titles=True)
g.map(plt.scatter,"ALB_Albumin", "A/G Ratio Albumin and Globulin Ratio",  edgecolor="w")
plt.subplots_adjust(top=0.9)

# %%
# Out:
#   Cell In[86], line 1
#     df_final. ALB Albumin.isnull()
#                   ^
# SyntaxError: invalid syntax

# %%
df_final.keys()
# Out:
# Index(['ID', 'Age of the patient', 'Gender of the patient', 'Total Bilirubin',
#        'Direct Bilirubin', ' Alkphos Alkaline Phosphotase',
#        ' Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase',
#        'Total Protiens', ' ALB Albumin',
#        'A/G Ratio Albumin and Globulin Ratio', 'City_Code', 'State_Code',
#        'Status'],
#       dtype='object')

# %%
# Plotting Gender(Male/Female) along with Albumin and Globulin Ratio and Total Protiens
g = sns.FacetGrid(df_final, col="Gender of the patient", row="Status", margin_titles=True)
g.map(plt.scatter,"A/G Ratio Albumin and Globulin Ratio", "Total Protiens",  edgecolor="w")
plt.subplots_adjust(top=0.9)

# %%
df_final.head(3)
# Out:
#        ID  Age of the patient Gender of the patient  Total Bilirubin  \
# 0  ID_001                65.0                Female              0.7
# 1  ID_002                62.0                  Male             10.9
# 2  ID_003                62.0                  Male              7.3
#
#    Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0               0.1                          187.0
# 1               5.5                          699.0
# 2               4.1                          490.0
#
#     Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                            16.0                             18.0
# 1                            64.0                            100.0
# 2                            60.0                             68.0
#
#    Total Protiens   ALB Albumin  A/G Ratio Albumin and Globulin Ratio  \
# 0             6.8           3.3                                  0.90
# ...

# %%
#pd.get_dummies(df_final['Gender of the patient'], prefix = 'Gender of the patient').head()
# Out:
#    Gender of the patient_0.0  Gender of the patient_1.0
# 0                      False                       True
# 1                       True                      False
# 2                       True                      False
# 3                       True                      False
# 4                       True                      False

# %% [markdown]
# # to here

# %%
df_final['Gender of the patient'].replace({'Female':1 , 'Male':0}, inplace=True)

# %%
df_final
# Out:
#              ID  Age of the patient  Gender of the patient  Total Bilirubin  \
# 0        ID_001                65.0                    1.0              0.7
# 1        ID_002                62.0                    0.0             10.9
# 2        ID_003                62.0                    0.0              7.3
# 3        ID_004                58.0                    0.0              1.0
# 4        ID_005                72.0                    0.0              3.9
# ...         ...                 ...                    ...              ...
# 30672  ID_30673                57.0                    1.0              2.6
# 30673  ID_30674                45.0                    0.0              1.3
# 30674  ID_30675                60.0                    1.0              0.7
# 30675  ID_30676                45.0                    0.0             14.2
# 30676  ID_30677                23.0                    0.0              1.4
#
# ...

# %%
df_final['City_Code'].nunique()
# Out:
# 29

# %%
# Box Plots for Outlier Detection:

numerical_features = ['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin', 'Alkphos Alkaline Phosphotase', 'Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase', 'Total Protiens', 'ALB Albumin', 'A/G Ratio Albumin and Globulin Ratio']
for feature in numerical_features:
    sns.boxplot(x='Status', y=feature, data=df_final)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 5
#       3 numerical_features = ['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin', 'Alkphos Alkaline Phosphotase', 'Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase', 'Total Protiens', 'ALB Albumin', 'A/G Ratio Albumin and Globulin Ratio']
#       4 for feature in numerical_features:
# ----> 5     sns.boxplot(x='Status', y=feature, data=df_final)
#       6     plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
# ...

# %%
# Visualize the distribution of categorical features such as Gender, State_Code, City_Code.

categorical_features = ['Gender of the patient', 'State_Code', 'City_Code']
for feature in categorical_features:
    sns.countplot(x=feature, hue='Status', data=df_final)
    plt.show()

# %%
# Bar plot for A/G Ratio Albumin and Globulin Ratio with liver Disease

plt.figure(figsize=(6, 4))
sns.barplot(x='Status', y='A/G Ratio Albumin and Globulin Ratio', data=df_final)
plt.show()

# %%
#Scatter Plot for Total Bilirubin vs. Direct Bilirubin with Liver Disease

plt.figure(figsize=(6, 4))
sns.scatterplot(x='Total Bilirubin', y='Direct Bilirubin', hue='Status', data=df_final)
plt.title('Scatter Plot for Total Bilirubin vs. Direct Bilirubin with Liver Disease')
plt.show()

# %% [markdown]
# #  1. Identify if there are any missing values in the data.

# %%
null = pd.DataFrame({'Null Value' : df_final.isna().sum(), 
                     'Percentage Null Value' : (df_final.isna().sum()) / (df_final.shape[0])*(100)})

# %%
null
# Out:
#                                       Null Value  Percentage Null Value
# ID                                             0               0.000000
# Age of the patient                             2               0.006520
# Gender of the patient                        898               2.927275
# Total Bilirubin                              644               2.099293
# Direct Bilirubin                             558               1.818952
#  Alkphos Alkaline Phosphotase                797               2.598038
#  Sgpt Alamine Aminotransferase               538               1.753757
# Sgot Aspartate Aminotransferase              463               1.509274
# Total Protiens                               464               1.512534
#  ALB Albumin                                 494               1.610327
# A/G Ratio Albumin and Globulin Ratio         559               1.822212
# City_Code                                      0               0.000000
# ...

# %%
null_heatmap = pd.DataFrame({'Null Value' : df_final.isna().sum()})
sns.heatmap(null_heatmap)
plt.show()

# %% [markdown]
# # 2. Any affect of age group on the occurrence of liver disease.

# %%
bins = [0, 20, 30, 40, 50, 60, 70, 80, 90, 100]
labels = ['0-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', '91-100']
df_new = df_final
df_new['Age_Group'] = pd.cut(df_new['Age of the patient'], bins=bins, labels=labels, right=False)

age_liver_disease = pd.crosstab(df_new['Age_Group'], df_new['Status'])
print("Effect of Age Group on Liver Disease:\n", age_liver_disease)
# Out:
# Effect of Age Group on Liver Disease:
#  Status        1     2
# Age_Group
# 0-20       1347   534
# 21-30      2770  1139
# 31-40      4443  1820
# 41-50      5180  2015
# 51-60      3685  1486
# 61-70      3049  1223
# 71-80      1324   509
# 81-90        56    29
# 91-100       51    15

# %%
age_liver_disease = pd.crosstab(df_final['Age_Group'], df_final['Status'])

age_liver_disease.plot(kind='bar') 
plt.title('Effect of Age Group on Liver Disease Status')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title='Status', labels=['Liver Patient', 'Not Liver Patient'], loc='upper right')
plt.show()

# %%
#plt.figure(figsize=(20,20))
#sns.heatmap(age_liver_disease.corr(), annot=True)

# %% [markdown]
# # 3.Relationship Between Different Factors and Liver Disease:

# %%
df_new = df_new.drop(["ID","City_Code","State_Code","Age_Group"],axis=1)

# %%
df_new.corr()
# Out:
#                                       Age of the patient  \
# Age of the patient                              1.000000
# Gender of the patient                          -0.033591
# Total Bilirubin                                -0.001581
# Direct Bilirubin                               -0.001476
#  Alkphos Alkaline Phosphotase                  -0.000758
#  Sgpt Alamine Aminotransferase                  0.000687
# Sgot Aspartate Aminotransferase                 0.006147
# Total Protiens                                 -0.007910
#  ALB Albumin                                   -0.015091
# A/G Ratio Albumin and Globulin Ratio           -0.017987
# Status                                         -0.004812
#
#                                       Gender of the patient  Total Bilirubin  \
# Age of the patient                                -0.033591        -0.001581
# Gender of the patient                              1.000000        -0.013020
# ...

# %%
sns.pairplot(df_new, hue='Status')
plt.show()

# Correlation with the target variable
correlation_with_status = df_new.corr()['Status'].sort_values(ascending=False)
print("Correlation with Liver Disease Status:\n", correlation_with_status)

# %%
# Display correlation matrix
correlation_matrix = df_new.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # 4. Dataset Balance, Missing Values, and Duplicate Records:

# %%
# Check if the dataset is balanced
class_count = df_final['Status'].value_counts()
print(class_count)

sns.countplot(x='Status', data=df_final)
plt.title('Class Distribution of Liver Disease')
plt.xlabel('Liver Disease Status')
plt.ylabel('Count')
plt.show()

print("Hence, the data is unbalanced")
# Out:
# Status
# 1    21907
# 2     8770
# Name: count, dtype: int64
# Hence, the data is unbalanced

# %%
# Check for duplicate records
duplicate_records = df_final.duplicated().sum()
print("Number of Duplicate Records:", duplicate_records)
# Out:
# Number of Duplicate Records: 0

# %% [markdown]
# # Analyze the effect of age group on liver disease using a bar plot.

# %%
age_liver_disease = pd.crosstab(df_final['Age_Group'], df_final['Status'])
age_liver_disease.plot(kind='bar')
plt.show()
